# %%
! pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: rdflib==7.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pandas==2.2.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: tabulate==0.9.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from rdflib==7.0.0->-r ../requirements.txt (line 1)) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from rdflib==7.0.0->-r ../requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->-r ../requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->-r ../requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->-r ../requirements.txt (line 2)) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas==2.2.2->-r ../requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: six in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from isodate<0.7.0,>=0.6.0->rdflib==7.0.0->-r ../requirements.txt (line 1)) (1.16.0)

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from tabulate import tabulate
from rdflib import Graph

def tabulate_result(results):
    rows = [row.asdict() for row in results]
    df = pd.DataFrame(rows)
    print(tabulate(df, headers=df.columns))

def run_sparql_query(file_path, query_file, file_format="ttl"):
    g = Graph()
    g.parse(file_path, format=file_format)

    with open(query_file, "r") as f:
        query = f.read()

    results = g.query(query)
    tabulate_result(results)

file_format = "ttl"

# %% [markdown]
# # Validator

# %%
from tosla_validator import validate_tosla_ttl

file_path = "../examples/amazon_ec2_sla.ttl"
with open(file_path, "r", encoding="utf-8") as f:
    ttl_content = f.read()

result = validate_tosla_ttl(ttl_content, "../validator/agreement_shape.ttl")
result
# Out:
# {'conforms': True, 'validation_time': 0.3345518112182617, 'violations': []}

# %%
from tosla_validator import validate_tosla_ttl

file_path = "../examples/cedalo_sla_2025.ttl"
with open(file_path, "r", encoding="utf-8") as f:
    ttl_content = f.read()

result = validate_tosla_ttl(ttl_content, "../validator/agreement_shape.ttl")
result
# Out:
# {'conforms': True, 'validation_time': 1.2362511157989502, 'violations': []}

# %%
from tosla_validator import validate_tosla_ttl

file_path = "../examples/alibaba_sla.ttl"
with open(file_path, "r", encoding="utf-8") as f:
    ttl_content = f.read()
    
result = validate_tosla_ttl(ttl_content, "../validator/agreement_shape.ttl")
result
# Out:
# {'conforms': True, 'validation_time': 0.31374406814575195, 'violations': []}

# %% [markdown]
# # Competency Questions

# %% [markdown]
# ### CQ1: Which **services** are governed by the SLA?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ1_services.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     agreement                        service                                serviceDescription
# --  -------------------------------  -------------------------------------  -----------------------------------------------------------------
#  0  http://example.com/amazonEC2SLA  http://example.com/ec2RegionService    EC2 instances deployed across multiple AZs within a single region
#  1  http://example.com/amazonEC2SLA  http://example.com/ec2InstanceService  Single Amazon EC2 instance

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ1_services.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     agreement                     service                                          serviceDescription
# --  ----------------------------  -----------------------------------------------  ------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  0  http://example.com/cedaloSLA  http://example.com/serviceSPlanSingleNode        Single Node service for Plan S: provides a standalone Pro Mosquitto MQTT broker, ideal for basic IoT deployments.
#  1  http://example.com/cedaloSLA  http://example.com/serviceSPlanHighAvailability  High Availability for Plan S: connects and synchronizes multiple instances of Pro Mosquitto MQTT broker, ensuring operational continuity in case of node failure.
#  2  http://example.com/cedaloSLA  http://example.com/serviceMPlanSingleNode        Single Node service for Plan M: dedicated Pro Mosquitto MQTT broker for medium-complexity IoT environments.
#  3  http://example.com/cedaloSLA  http://example.com/serviceMPlanHighAvailability  High Availability for Plan M: synchronized cluster of Pro Mosquitto MQTT brokers for high availability and fault tolerance.
#  4  http://example.com/cedaloSLA  http://example.com/serviceLPlanSingleNode        Single Node service for Plan L: Pro Mosquitto MQTT broker optimized for larger-scale IoT workloads.
#  5  http://example.com/cedaloSLA  http://example.com/serviceLPlanHighAvailability  High Availability for Plan L: deployment of multiple synchronized Pro Mosquitto MQTT brokers in a cluster, ensuring uninterrupted service.
#  6  http://example.com/cedaloSLA  http://example.com/serviceEnterprisePlan         Enterprise HA Service: Pro Mosquitto MQTT platform with full synchronization of state, configuration, and data between brokers, for maximum reliability and scalability.

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ1_services.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     agreement                         service                                 serviceDescription
# --  --------------------------------  --------------------------------------  ------------------------------------------------------------------------------------------------------------
#  0  http://example.com/alibabaECSSLA  http://example.com/instanceEcsService   Alibaba Cloud Elastic Compute Service (ECS) instance offering covered by this SLA.
#  1  http://example.com/alibabaECSSLA  http://example.com/multiZoneEcsService  Alibaba Cloud ECS instances deployed in multiple zones within the same region, subject to higher uptime SLA.

# %% [markdown]
# ### CQ2: Which **quality of service** levels does a service deliver?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ2_slo.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                commitment                                    description                                                                                                SLI                        operator                          objectiveValue
# --  -------------------------------------  --------------------------------------------  ---------------------------------------------------------------------------------------------------------  -------------------------  --------------------------------  ----------------
#  0  http://example.com/ec2InstanceService  http://example.com/commitmentEC2Instance      AWS must provide at least 99.5% monthly uptime for single EC2 instance                                     Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq  99.5
#  1  http://example.com/ec2InstanceService  http://example.com/commitmentPerInstanceHour  AWS must ensure that each EC2 instance is unavailable no more than 6 minutes within any given clock hour.  nan                        http://www.w3.org/ns/odrl/2/lteq  PT6M
#  2  http://example.com/ec2RegionService    http://example.com/commitmentEC2Region        AWS must provide at least 99.99% monthly uptime for Region EC2                                             Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq  99.99

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ2_slo.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                          commitment                                          description                                                 SLI                        operator                            objectiveValue
# --  -----------------------------------------------  --------------------------------------------------  ----------------------------------------------------------  -------------------------  --------------------------------  ----------------
#  0  http://example.com/serviceEnterprisePlan         http://example.com/commitmentEnterprisePlan         Cedalo must provide an uptime percentage of at least 99.9%  Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq              99.9
#  1  http://example.com/serviceLPlanHighAvailability  http://example.com/commitmentLPlanHighAvailability  Cedalo must provide an uptime percentage of at least 99.9%  Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq              99.9
#  2  http://example.com/serviceLPlanSingleNode        http://example.com/commitmentLPlanSingleNode        Cedalo must provide an uptime percentage of at least 98.9%  Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq              98.9
#  3  http://example.com/serviceMPlanHighAvailability  http://example.com/commitmentMPlanHighAvailability  Cedalo must provide an uptime percentage of at least 99.5%  Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq              99.5
#  4  http://example.com/serviceMPlanSingleNode        http://example.com/commitmentMPlanSingleNode        Cedalo must provide an uptime percentage of at least 98.5%  Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq              98.5
#  5  http://example.com/serviceSPlanHighAvailability  http://example.com/commitmentSPlanHighAvailability  Cedalo must provide an uptime percentage of at least 98.5%  Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq              98.5
#  6  http://example.com/serviceSPlanSingleNode        http://example.com/commitmentSPlanSingleNode        Cedalo must provide an uptime percentage of at least 97%    Monthly Uptime Percentage  http://www.w3.org/ns/odrl/2/gteq              97

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ2_slo.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                 commitment                                    description                                                               SLI                                                         operator                            objectiveValue
# --  --------------------------------------  --------------------------------------------  ------------------------------------------------------------------------  ----------------------------------------------------------  --------------------------------  ----------------
#  0  http://example.com/instanceEcsService   http://example.com/uptimeCommitmentInstance   Alibaba must provide at least 99.975% uptime per instance.                Monthly Uptime Percentage - Instance Unavailable            http://www.w3.org/ns/odrl/2/gteq            99.975
#  1  http://example.com/multiZoneEcsService  http://example.com/uptimeCommitmentMultiZone  Alibaba must provide at least 99.995% uptime for multi-zone deployments.  Monthly Uptime Percentage - Multi-zone Service Unavailable  http://www.w3.org/ns/odrl/2/gteq            99.995

# %% [markdown]
# ### CQ3: Which particular **properties of a service** are guaranteed to have certain values?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ3_sli.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                SLI
# --  -------------------------------------  ------------------------------------------------------
#  0  http://example.com/ec2InstanceService  http://example.com/monthlyUptimeMetric
#  1  http://example.com/ec2InstanceService  http://example.com/unavailabilityDurationPerHourMetric
#  2  http://example.com/ec2RegionService    http://example.com/monthlyUptimeMetric

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ3_sli.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                          SLI
# --  -----------------------------------------------  --------------------------------------
#  0  http://example.com/serviceEnterprisePlan         http://example.com/monthlyUptimeMetric
#  1  http://example.com/serviceLPlanHighAvailability  http://example.com/monthlyUptimeMetric
#  2  http://example.com/serviceLPlanSingleNode        http://example.com/monthlyUptimeMetric
#  3  http://example.com/serviceMPlanHighAvailability  http://example.com/monthlyUptimeMetric
#  4  http://example.com/serviceMPlanSingleNode        http://example.com/monthlyUptimeMetric
#  5  http://example.com/serviceSPlanHighAvailability  http://example.com/monthlyUptimeMetric
#  6  http://example.com/serviceSPlanSingleNode        http://example.com/monthlyUptimeMetric

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ3_sli.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                 SLI
# --  --------------------------------------  --------------------------------------
#  0  http://example.com/instanceEcsService   http://example.com/monthlyUptimeMetric
#  1  http://example.com/multiZoneEcsService  http://example.com/monthlyUptimeMetric

# %% [markdown]
# ### CQ4: Which **compensations** are offered if the guaranteed value of a property is not honored?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ4_compensations.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                compensation                                   SLI                                               interval                          credit
# --  -------------------------------------  ---------------------------------------------  ------------------------------------------------  ------------------------------  --------
#  0  http://example.com/ec2InstanceService  http://example.com/compensationEC2Instance10   http://example.com/monthlyUptimePercentage        value ≥ 99.0 AND value < 99.5         10
#  1  http://example.com/ec2InstanceService  http://example.com/compensationEC2Instance30   http://example.com/monthlyUptimePercentage        value ≥ 95.0 AND value < 99.0         30
#  2  http://example.com/ec2InstanceService  http://example.com/compensationEC2Instance100  http://example.com/monthlyUptimePercentage        value < 99.5                         100
#  3  http://example.com/ec2InstanceService  http://example.com/compensatePerHour           http://example.com/unavailabilityDurationPerHour  value > PT6M                         100
#  4  http://example.com/ec2RegionService    http://example.com/compensationEC2Region10     http://example.com/monthlyUptimePercentage        value ≥ 99.0 AND value < 99.99        10
#  5  http://example.com/ec2RegionService    http://example.com/compensationEC2Region30     http://example.com/monthlyUptimePercentage        value ≥ 95.0 AND value < 99.0         30
#  6  http://example.com/ec2RegionService    http://example.com/compensationEC2Region100    http://example.com/monthlyUptimePercentage        value < 99.5                         100

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ4_compensations.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                          compensation                                              SLI                                         interval                           credit
# --  -----------------------------------------------  --------------------------------------------------------  ------------------------------------------  -------------------------------  --------
#  0  http://example.com/serviceEnterprisePlan         http://example.com/compensation7_5_EnterprisePlan         http://example.com/monthlyUptimePercentage  value ≥ 98.99 AND value < 99.99       7.5
#  1  http://example.com/serviceEnterprisePlan         http://example.com/compensation15_EnterprisePlan          http://example.com/monthlyUptimePercentage  value ≥ 89.99 AND value < 98.99      15
#  2  http://example.com/serviceEnterprisePlan         http://example.com/compensation25_EnterprisePlan          http://example.com/monthlyUptimePercentage  value < 89.99                        25
#  3  http://example.com/serviceLPlanHighAvailability  http://example.com/compensation7_5_LPlanHighAvailability  http://example.com/monthlyUptimePercentage  value ≥ 98.9 AND value < 99.9         7.5
#  4  http://example.com/serviceLPlanHighAvailability  http://example.com/compensation15_LPlanHighAvailability   http://example.com/monthlyUptimePercentage  value ≥ 89.9 AND value < 98.9        15
#  5  http://example.com/serviceLPlanHighAvailability  http://example.com/compensation25_LPlanHighAvailability   http://example.com/monthlyUptimePercentage  value < 89.9                         25
#  6  http://example.com/serviceLPlanSingleNode        http://example.com/compensation7_5_LPlanSingleNode        http://example.com/monthlyUptimePercentage  value ≥ 97.9 AND value < 98.9         7.5
#  7  http://example.com/serviceLPlanSingleNode        http://example.com/compensation15_LPlanSingleNode         http://example.com/monthlyUptimePercentage  value ≥ 88.9 AND value < 97.9        15
#  8  http://example.com/serviceLPlanSingleNode        http://example.com/compensation25_LPlanSingleNode         http://example.com/monthlyUptimePercentage  value < 88.9                         25
#  9  http://example.com/serviceMPlanHighAvailability  http://example.com/compensation7_5_MPlanHighAvailability  http://example.com/monthlyUptimePercentage  value ≥ 98.5 AND value < 99.5         7.5
# 10  http://example.com/serviceMPlanHighAvailability  http://example.com/compensation15_MPlanHighAvailability   http://example.com/monthlyUptimePercentage  value ≥ 89.5 AND value < 98.5        15
# 11  http://example.com/serviceMPlanHighAvailability  http://example.com/compensation25_MPlanHighAvailability   http://example.com/monthlyUptimePercentage  value < 89.5                         25
# 12  http://example.com/serviceMPlanSingleNode        http://example.com/compensation7_5_MPlanSingleNode        http://example.com/monthlyUptimePercentage  value ≥ 97.5 AND value < 98.5         7.5
# 13  http://example.com/serviceMPlanSingleNode        http://example.com/compensation15_MPlanSingleNode         http://example.com/monthlyUptimePercentage  value ≥ 88.5 AND value < 97.5        15
# 14  http://example.com/serviceMPlanSingleNode        http://example.com/compensation25_MPlanSingleNode         http://example.com/monthlyUptimePercentage  value < 88.5                         25
# 15  http://example.com/serviceSPlanHighAvailability  http://example.com/compensation7_5_SPlanHighAvailability  http://example.com/monthlyUptimePercentage  value ≥ 97.5 AND value < 98.5         7.5
# 16  http://example.com/serviceSPlanHighAvailability  http://example.com/compensation15_SPlanHighAvailability   http://example.com/monthlyUptimePercentage  value ≥ 88.5 AND value < 97.5        15
# 17  http://example.com/serviceSPlanHighAvailability  http://example.com/compensation25_SPlanHighAvailability   http://example.com/monthlyUptimePercentage  value < 88.5                         25
# 18  http://example.com/serviceSPlanSingleNode        http://example.com/compensation7_5_SPlanSingleNode        http://example.com/monthlyUptimePercentage  value ≥ 96 AND value < 97             7.5
# 19  http://example.com/serviceSPlanSingleNode        http://example.com/compensation15_SPlanSingleNode         http://example.com/monthlyUptimePercentage  value ≥ 87 AND value < 96            15
# 20  http://example.com/serviceSPlanSingleNode        http://example.com/compensation25_SPlanSingleNode         http://example.com/monthlyUptimePercentage  value < 87                           25

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ4_compensations.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                 compensation                                 SLI                                                             interval                           credit
# --  --------------------------------------  -------------------------------------------  --------------------------------------------------------------  -------------------------------  --------
#  0  http://example.com/instanceEcsService   http://example.com/compensationInstance10    http://example.com/monthlyUptimePercentageInstanceUnavailable   value ≥ 99.0 AND value < 99.975        10
#  1  http://example.com/instanceEcsService   http://example.com/compensationInstance25    http://example.com/monthlyUptimePercentageInstanceUnavailable   value ≥ 95.0 AND value < 99.0          25
#  2  http://example.com/instanceEcsService   http://example.com/compensationInstance100   http://example.com/monthlyUptimePercentageInstanceUnavailable   value < 95.0                          100
#  3  http://example.com/multiZoneEcsService  http://example.com/compensationMultiZone10   http://example.com/monthlyUptimePercentageMultiZoneUnavailable  value ≥ 99.0 AND value < 99.995        10
#  4  http://example.com/multiZoneEcsService  http://example.com/compensationMultiZone25   http://example.com/monthlyUptimePercentageMultiZoneUnavailable  value ≥ 95.0 AND value < 99.0          25
#  5  http://example.com/multiZoneEcsService  http://example.com/compensationMultiZone100  http://example.com/monthlyUptimePercentageMultiZoneUnavailable  value < 95.0                          100

# %% [markdown]
# ### CQ5: Who is the **responsible party** for enforcing the guaranteed service level values?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ5_responsable.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                commitment                                    assignee                   assigneeName
# --  -------------------------------------  --------------------------------------------  -------------------------  -------------------
#  0  http://example.com/ec2InstanceService  http://example.com/commitmentEC2Instance      http://example.com/amazon  Amazon Web Services
#  1  http://example.com/ec2InstanceService  http://example.com/commitmentPerInstanceHour  http://example.com/amazon  Amazon Web Services
#  2  http://example.com/ec2RegionService    http://example.com/commitmentEC2Region        http://example.com/amazon  Amazon Web Services

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ5_responsable.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                          commitment                                          assignee                   assigneeName
# --  -----------------------------------------------  --------------------------------------------------  -------------------------  --------------------
#  0  http://example.com/serviceEnterprisePlan         http://example.com/commitmentEnterprisePlan         http://example.com/cedalo  Cedalo MQTT Platform
#  1  http://example.com/serviceLPlanHighAvailability  http://example.com/commitmentLPlanHighAvailability  http://example.com/cedalo  Cedalo MQTT Platform
#  2  http://example.com/serviceLPlanSingleNode        http://example.com/commitmentLPlanSingleNode        http://example.com/cedalo  Cedalo MQTT Platform
#  3  http://example.com/serviceMPlanHighAvailability  http://example.com/commitmentMPlanHighAvailability  http://example.com/cedalo  Cedalo MQTT Platform
#  4  http://example.com/serviceMPlanSingleNode        http://example.com/commitmentMPlanSingleNode        http://example.com/cedalo  Cedalo MQTT Platform
#  5  http://example.com/serviceSPlanHighAvailability  http://example.com/commitmentSPlanHighAvailability  http://example.com/cedalo  Cedalo MQTT Platform
#  6  http://example.com/serviceSPlanSingleNode        http://example.com/commitmentSPlanSingleNode        http://example.com/cedalo  Cedalo MQTT Platform

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ5_responsable.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                 commitment                                    assignee                    assigneeName
# --  --------------------------------------  --------------------------------------------  --------------------------  --------------
#  0  http://example.com/instanceEcsService   http://example.com/uptimeCommitmentInstance   http://example.com/alibaba  Alibaba Cloud
#  1  http://example.com/multiZoneEcsService  http://example.com/uptimeCommitmentMultiZone  http://example.com/alibaba  Alibaba Cloud

# %% [markdown]
# ### CQ6: Who is the **responsible party for monitoring and computing** the guaranteed values?
#
# Duty commitment liability

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ6_monitoring.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                          liabilityType                               liableParty                  liabilityDescription
# --  --------------------------------------------  ------------------------------------------  ---------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  0  http://example.com/commitmentEC2Instance      https://w3id.org/tosla/conditionEvaluation  http://example.com/customer  The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  1  http://example.com/commitmentEC2Instance      https://w3id.org/tosla/metricComputation    http://example.com/customer  The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
#  2  http://example.com/commitmentEC2Region        https://w3id.org/tosla/conditionEvaluation  http://example.com/customer  The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  3  http://example.com/commitmentEC2Region        https://w3id.org/tosla/metricComputation    http://example.com/customer  The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
#  4  http://example.com/commitmentPerInstanceHour  https://w3id.org/tosla/conditionEvaluation  http://example.com/amazon    The provider is responsible for monitoring the actual uptime of the service.
#  5  http://example.com/commitmentPerInstanceHour  https://w3id.org/tosla/metricComputation    http://example.com/amazon    The provider is responsible for calculating the monthly uptime values.

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ6_monitoring.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                                liabilityType                               liableParty                                liabilityDescription
# --  --------------------------------------------------  ------------------------------------------  -----------------------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  0  http://example.com/commitmentEnterprisePlan         https://w3id.org/tosla/conditionEvaluation  http://example.com/customerEnterprisePlan  The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  1  http://example.com/commitmentEnterprisePlan         https://w3id.org/tosla/metricComputation    http://example.com/customerEnterprisePlan  The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
#  2  http://example.com/commitmentLPlanHighAvailability  https://w3id.org/tosla/conditionEvaluation  http://example.com/customerLPlan           The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  3  http://example.com/commitmentLPlanHighAvailability  https://w3id.org/tosla/metricComputation    http://example.com/customerLPlan           The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
#  4  http://example.com/commitmentLPlanSingleNode        https://w3id.org/tosla/conditionEvaluation  http://example.com/customerLPlan           The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  5  http://example.com/commitmentLPlanSingleNode        https://w3id.org/tosla/metricComputation    http://example.com/customerLPlan           The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
#  6  http://example.com/commitmentMPlanHighAvailability  https://w3id.org/tosla/conditionEvaluation  http://example.com/customerMPlan           The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  7  http://example.com/commitmentMPlanHighAvailability  https://w3id.org/tosla/metricComputation    http://example.com/customerMPlan           The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
#  8  http://example.com/commitmentMPlanSingleNode        https://w3id.org/tosla/conditionEvaluation  http://example.com/customerMPlan           The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  9  http://example.com/commitmentMPlanSingleNode        https://w3id.org/tosla/metricComputation    http://example.com/customerMPlan           The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
# 10  http://example.com/commitmentSPlanHighAvailability  https://w3id.org/tosla/conditionEvaluation  http://example.com/customerSPlan           The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
# 11  http://example.com/commitmentSPlanHighAvailability  https://w3id.org/tosla/metricComputation    http://example.com/customerSPlan           The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
# 12  http://example.com/commitmentSPlanSingleNode        https://w3id.org/tosla/conditionEvaluation  http://example.com/customerSPlan           The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
# 13  http://example.com/commitmentSPlanSingleNode        https://w3id.org/tosla/metricComputation    http://example.com/customerSPlan           The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ6_monitoring.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                          liabilityType                               liableParty                  liabilityDescription
# --  --------------------------------------------  ------------------------------------------  ---------------------------  -------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  0  http://example.com/uptimeCommitmentInstance   https://w3id.org/tosla/conditionEvaluation  http://example.com/customer  The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  1  http://example.com/uptimeCommitmentInstance   https://w3id.org/tosla/metricComputation    http://example.com/customer  The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.
#  2  http://example.com/uptimeCommitmentMultiZone  https://w3id.org/tosla/conditionEvaluation  http://example.com/customer  The customer is responsible for monitoring and compiling all information regarding service unavailability in order to claim compensation.
#  3  http://example.com/uptimeCommitmentMultiZone  https://w3id.org/tosla/metricComputation    http://example.com/customer  The customer is responsible for calculating the total downtime affecting their services, in order to determine whether the guaranteed service levels have been met.

# %% [markdown]
# ### CQ7: During which **period of time** a guarantee is offered?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ7_period_time.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                duty                                          duration
# --  -------------------------------------  --------------------------------------------  ----------
#  0  http://example.com/ec2InstanceService  http://example.com/commitmentEC2Instance      P30D
#  1  http://example.com/ec2InstanceService  http://example.com/commitmentPerInstanceHour  PT1H
#  2  http://example.com/ec2RegionService    http://example.com/commitmentEC2Region        P30D

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ7_period_time.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                          duty                                                duration
# --  -----------------------------------------------  --------------------------------------------------  ----------
#  0  http://example.com/serviceEnterprisePlan         http://example.com/commitmentEnterprisePlan         P30D
#  1  http://example.com/serviceLPlanHighAvailability  http://example.com/commitmentLPlanHighAvailability  P30D
#  2  http://example.com/serviceLPlanSingleNode        http://example.com/commitmentLPlanSingleNode        P30D
#  3  http://example.com/serviceMPlanHighAvailability  http://example.com/commitmentMPlanHighAvailability  P30D
#  4  http://example.com/serviceMPlanSingleNode        http://example.com/commitmentMPlanSingleNode        P30D
#  5  http://example.com/serviceSPlanHighAvailability  http://example.com/commitmentSPlanHighAvailability  P30D
#  6  http://example.com/serviceSPlanSingleNode        http://example.com/commitmentSPlanSingleNode        P30D

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ7_period_time.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     service                                 duty                                          duration
# --  --------------------------------------  --------------------------------------------  ----------
#  0  http://example.com/instanceEcsService   http://example.com/uptimeCommitmentInstance   P30D
#  1  http://example.com/multiZoneEcsService  http://example.com/uptimeCommitmentMultiZone  P30D

# %% [markdown]
# ### CQ8: How are current values of a **service property computed**?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ8_SLI_expression.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     leftOperand                                 metricLabel                expression                                     unit                                interval
# --  ------------------------------------------  -------------------------  ---------------------------------------------  ----------------------------------  ----------------------------------
#  0  http://example.com/monthlyUptimePercentage  Monthly Uptime Percentage  100 - (100 * ?downtimeMinutes / totalMinutes)  http://qudt.org/vocab/unit#Percent  http://example.com/monthlyInterval

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/competency_questions/CQ8_SLI_expression.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     leftOperand                                 metricLabel                expression                                unit                                interval
# --  ------------------------------------------  -------------------------  ----------------------------------------  ----------------------------------  ----------------------------------
#  0  http://example.com/monthlyUptimePercentage  Monthly Uptime Percentage  100 - (100 * ?inactivityMinutes / 43200)  http://qudt.org/vocab/unit#Percent  http://example.com/monthlyInterval

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/competency_questions/CQ8_SLI_expression.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     leftOperand                                                     metricLabel                                                 expression                                                                unit                                interval
# --  --------------------------------------------------------------  ----------------------------------------------------------  ------------------------------------------------------------------------  ----------------------------------  ----------------------------------
#  0  http://example.com/monthlyUptimePercentageInstanceUnavailable   Monthly Uptime Percentage - Instance Unavailable            100 * ((?serviceCycleMinutes - ?downtimeMinutes) / ?serviceCycleMinutes)  http://qudt.org/vocab/unit#Percent  http://example.com/monthlyInterval
#  1  http://example.com/monthlyUptimePercentageMultiZoneUnavailable  Monthly Uptime Percentage - Multi-zone Service Unavailable  100 * ((?serviceCycleMinutes - ?downtimeMinutes) / ?serviceCycleMinutes)  http://qudt.org/vocab/unit#Percent  http://example.com/monthlyInterval

# %% [markdown]
# ------------

# %% [markdown]
# ## Unfair Terms
#
# #### Arbitration
# Does the agreement include any arbitration clauses? If so, are they related to litigation?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/arbitration.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/arbitration.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/arbitration.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# #### Unfair Choice by Law
# Are there any dispute resolution clauses that apply a law other than the consumer’s place of residence?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/choice_of_law.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/choice_of_law.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/choice_of_law.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# #### Content Removal
# Is removal allowed without reason, notice, or possibility of recovery?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/content_removal.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/content_removal.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/content_removal.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# #### Unfair Contract by Using
# Is the consumer considered to have accepted the contract by mere use or implied consent?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/contract_by_use.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/contract_by_use.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/contract_by_use.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# #### Unfair Jurisdiction
# Does the dispute take place in the courts of a city or country other than the consumer's country of residence?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/jurisdiction.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/jurisdiction.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/jurisdiction.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# #### Unfair Limitation of Liability
# Does the supplier exclude or limit his liabilities or any contractual obligations?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/limitation_of_liability.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     liability                                       description                                                                                                                                                      limitationOn                     type                                     liableParty
# --  ----------------------------------------------  ---------------------------------------------------------------------------------------------------------------------------------------------------------------  -------------------------------  ---------------------------------------  -------------------------
#  0  http://example.com/liabilitySuspension          Suspension or termination of EC2 service due to breach of AWS terms by the Customer.                                                                             http://example.com/amazonEC2SLA  https://w3id.org/tosl/breachOfContract   http://example.com/amazon
#  1  http://example.com/liabilityNonMeasuredFactors  Other factors affecting availability not used in Monthly Uptime Percentage or Instance Uptime Percentage calculations. Credits may be issued at AWS discretion.  http://example.com/amazonEC2SLA  https://w3id.org/tosl/anyIndirectDamage  http://example.com/amazon

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/limitation_of_liability.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     liability                                   description                                                                                    limitationOn                  type                                       liableParty
# --  ------------------------------------------  ---------------------------------------------------------------------------------------------  ----------------------------  -----------------------------------------  -------------------------
#  0  http://example.com/liabilityBreachContract  Situations where Cedalo suspends access due to violations of the Customer’s obligations.       http://example.com/cedaloSLA  https://w3id.org/tosl/breachOfContract     http://example.com/cedalo
#  1  http://example.com/liabilityForceMajeure    Unavailability due to force majeure, DDoS attacks, or similar events beyond Cedalo’s control.  http://example.com/cedaloSLA  https://w3id.org/tosl/anyIndirectDamage    http://example.com/cedalo
#  2  http://example.com/liabilityForceMajeure    Unavailability due to force majeure, DDoS attacks, or similar events beyond Cedalo’s control.  http://example.com/cedaloSLA  https://w3id.org/tosl/harmCausedByMalware  http://example.com/cedalo

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/limitation_of_liability.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     liability                                       description                                                                                                            limitationOn                      type                                     liableParty
# --  ----------------------------------------------  ---------------------------------------------------------------------------------------------------------------------  --------------------------------  ---------------------------------------  --------------------------
#  0  http://example.com/liabilitySuspensionContract  Suspension or termination of ECS Service due to breach of Alibaba Cloud terms by the Customer.                         http://example.com/alibabaECSSLA  https://w3id.org/tosl/breachOfContract   http://example.com/alibaba
#  1  http://example.com/liabilityIllegalUse          Unavailability caused by illegal or unlawful use of the Service, or breach of Alibaba Cloud terms and conditions.      http://example.com/alibabaECSSLA  https://w3id.org/tosl/breachOfContract   http://example.com/alibaba
#  2  http://example.com/liabilityCriticalISPFailure  Events resulting from critical accidents or failures of relevant internet service providers or scheduled maintenance.  http://example.com/alibabaECSSLA  https://w3id.org/tosl/anyIndirectDamage  http://example.com/alibaba
#  3  http://example.com/liabilityEphemeralDiskLoss   Events resulting from loss of data stored in ephemeral or local disks following critical failures of the host.         http://example.com/alibabaECSSLA  https://w3id.org/tosl/anyLoss            http://example.com/alibaba

# %% [markdown]
# #### Unfair Unilateral Change
# Are changes made unilaterally without reason or prior notice?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/change.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/change.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/change.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     permission                                    description                                                                                                                                                                                   action                              target
# --  --------------------------------------------  --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  ----------------------------------  --------------------------------
#  0  http://example.com/slaModificationPermission  Alibaba reserves the right to unilaterally modify the terms of this SLA by posting an amended version on the Alibaba Cloud website. Continued use of the Service shall be deemed acceptance.  http://www.w3.org/ns/odrl/2/modify  http://example.com/alibabaECSSLA

# %% [markdown]
# #### Unfair Unilateral Termination
# Is it permitted to terminate the contract unilaterally, without justification or prior notice?

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/unfair_terms/termination.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/unfair_terms/termination.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/unfair_terms/termination.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# ------------

# %% [markdown]
# ### Number of Rules
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_rules.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalElements
# --  ---------------
#  0               12

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_rules.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalElements
# --  ---------------
#  0               37

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_rules.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalElements
# --  ---------------
#  0               13

# %% [markdown]
# ## Permissions and number of permissions

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalPermissions
# --  ------------------
#  0                   0

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalPermissions
# --  ------------------
#  0                   1

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     permission                                actions                             targets                                                                                                                                                                                                                                                                                                                       assignee
# --  ----------------------------------------  ----------------------------------  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -------------------------
#  0  http://example.com/permissionMaintenance  http://www.w3.org/ns/odrl/2/modify  http://example.com/serviceSPlanSingleNode, http://example.com/serviceSPlanHighAvailability, http://example.com/serviceMPlanSingleNode, http://example.com/serviceMPlanHighAvailability, http://example.com/serviceLPlanSingleNode, http://example.com/serviceLPlanHighAvailability, http://example.com/serviceEnterprisePlan  http://example.com/cedalo

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalPermissions
# --  ------------------
#  0                   1

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     permission                                    actions                             targets                           assignee
# --  --------------------------------------------  ----------------------------------  --------------------------------  --------------------------
#  0  http://example.com/slaModificationPermission  http://www.w3.org/ns/odrl/2/modify  http://example.com/alibabaECSSLA  http://example.com/alibaba

# %% [markdown]
# #### Provider

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     permission                                actions                             targets                                                                                                                                                                                                                                                                                                                       assignee
# --  ----------------------------------------  ----------------------------------  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -------------------------
#  0  http://example.com/permissionMaintenance  http://www.w3.org/ns/odrl/2/modify  http://example.com/serviceSPlanSingleNode, http://example.com/serviceSPlanHighAvailability, http://example.com/serviceMPlanSingleNode, http://example.com/serviceMPlanHighAvailability, http://example.com/serviceLPlanSingleNode, http://example.com/serviceLPlanHighAvailability, http://example.com/serviceEnterprisePlan  http://example.com/cedalo

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     permission                                    actions                             targets                           assignee
# --  --------------------------------------------  ----------------------------------  --------------------------------  --------------------------
#  0  http://example.com/slaModificationPermission  http://www.w3.org/ns/odrl/2/modify  http://example.com/alibabaECSSLA  http://example.com/alibaba

# %% [markdown]
# #### Customer

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_permissions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# ## Duties and number of duties

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalDuties
# --  -------------
#  0             12

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                           actions                                 targets                                assignee
# --  ---------------------------------------------  --------------------------------------  -------------------------------------  ---------------------------
#  0  http://example.com/commitmentEC2Region         https://w3id.org/tosla/guarantee        http://example.com/ec2RegionService    http://example.com/amazon
#  1  http://example.com/customerClaimEC2Region      https://w3id.org/tosl/claim             http://example.com/ec2RegionService    http://example.com/customer
#  2  http://example.com/compensationEC2Region10     http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2RegionService    http://example.com/amazon
#  3  http://example.com/compensationEC2Region30     http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2RegionService    http://example.com/amazon
#  4  http://example.com/compensationEC2Region100    http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2RegionService    http://example.com/amazon
#  5  http://example.com/commitmentEC2Instance       https://w3id.org/tosla/guarantee        http://example.com/ec2InstanceService  http://example.com/amazon
#  6  http://example.com/customerClaimEC2Instance    https://w3id.org/tosl/claim             http://example.com/ec2RegionService    http://example.com/customer
#  7  http://example.com/compensationEC2Instance10   http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon
#  8  http://example.com/compensationEC2Instance30   http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon
#  9  http://example.com/compensationEC2Instance100  http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon
# 10  http://example.com/commitmentPerInstanceHour   https://w3id.org/tosla/guarantee        http://example.com/ec2InstanceService  http://example.com/amazon
# 11  http://example.com/compensatePerHour           http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalDuties
# --  -------------
#  0             36

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                                      actions                                 targets                                                                                                                                                                                                                                                                                                                       assignee
# --  --------------------------------------------------------  --------------------------------------  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -----------------------------------------
#  0  http://example.com/commitmentSPlanSingleNode              https://w3id.org/tosla/guarantee        http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  1  http://example.com/customerSPlanSingleNodeClaim           https://w3id.org/tosl/claim             http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/customerSPlan
#  2  http://example.com/compensation7_5_SPlanSingleNode        http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  3  http://example.com/compensation15_SPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  4  http://example.com/compensation25_SPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  5  http://example.com/commitmentSPlanHighAvailability        https://w3id.org/tosla/guarantee        http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
#  6  http://example.com/customerSPlanHighAvailabilityClaim     https://w3id.org/tosl/claim             http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/customerSPlan
#  7  http://example.com/compensation7_5_SPlanHighAvailability  http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
#  8  http://example.com/compensation15_SPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
#  9  http://example.com/compensation25_SPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 10  http://example.com/commitmentMPlanSingleNode              https://w3id.org/tosla/guarantee        http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 11  http://example.com/customerMPlanSingleNodeClaim           https://w3id.org/tosl/claim             http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/customerMPlan
# 12  http://example.com/compensation7_5_MPlanSingleNode        http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 13  http://example.com/compensation15_MPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 14  http://example.com/compensation25_MPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 15  http://example.com/commitmentMPlanHighAvailability        https://w3id.org/tosla/guarantee        http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 16  http://example.com/customerMPlanHighAvailabilityClaim     https://w3id.org/tosl/claim             http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/customerSPlan
# 17  http://example.com/compensation7_5_MPlanHighAvailability  http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 18  http://example.com/compensation15_MPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 19  http://example.com/compensation25_MPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 20  http://example.com/commitmentLPlanSingleNode              https://w3id.org/tosla/guarantee        http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 21  http://example.com/customerLPlanSingleNodeClaim           https://w3id.org/tosl/claim             http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/customerLPlan
# 22  http://example.com/compensation7_5_LPlanSingleNode        http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 23  http://example.com/compensation15_LPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 24  http://example.com/compensation25_LPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 25  http://example.com/commitmentLPlanHighAvailability        https://w3id.org/tosla/guarantee        http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 26  http://example.com/customerLPlanHighAvailabilityClaim     https://w3id.org/tosl/claim             http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/customerLPlan
# 27  http://example.com/compensation7_5_LPlanHighAvailability  http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 28  http://example.com/compensation15_LPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 29  http://example.com/compensation25_LPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 30  http://example.com/commitmentEnterprisePlan               https://w3id.org/tosla/guarantee        http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 31  http://example.com/customerEnterprisePlanClaim            https://w3id.org/tosl/claim             http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/customerEnterprisePlan
# 32  http://example.com/compensation7_5_EnterprisePlan         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 33  http://example.com/compensation15_EnterprisePlan          http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 34  http://example.com/compensation25_EnterprisePlan          http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 35  http://example.com/serviceChangeNotification              http://www.w3.org/ns/odrl/2/inform      http://example.com/serviceSPlanSingleNode, http://example.com/serviceSPlanHighAvailability, http://example.com/serviceMPlanSingleNode, http://example.com/serviceMPlanHighAvailability, http://example.com/serviceLPlanSingleNode, http://example.com/serviceLPlanHighAvailability, http://example.com/serviceEnterprisePlan  http://example.com/cedalo

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalDuties
# --  -------------
#  0             12

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                            actions                                 targets                                 assignee
# --  ----------------------------------------------  --------------------------------------  --------------------------------------  ---------------------------
#  0  http://example.com/uptimeCommitmentInstance     https://w3id.org/tosla/guarantee        http://example.com/instanceEcsService   http://example.com/alibaba
#  1  http://example.com/customerClaimInstance        https://w3id.org/tosl/claim             http://example.com/instanceEcsService   http://example.com/customer
#  2  http://example.com/compensationInstance10       http://www.w3.org/ns/odrl/2/compensate  http://example.com/instanceEcsService   http://example.com/alibaba
#  3  http://example.com/compensationInstance25       http://www.w3.org/ns/odrl/2/compensate  http://example.com/instanceEcsService   http://example.com/alibaba
#  4  http://example.com/compensationInstance100      http://www.w3.org/ns/odrl/2/compensate  http://example.com/instanceEcsService   http://example.com/alibaba
#  5  http://example.com/uptimeCommitmentMultiZone    https://w3id.org/tosla/guarantee        http://example.com/multiZoneEcsService  http://example.com/alibaba
#  6  http://example.com/customerClaimMultiZone       https://w3id.org/tosl/claim             http://example.com/multiZoneEcsService  http://example.com/customer
#  7  http://example.com/compensationMultiZone10      http://www.w3.org/ns/odrl/2/compensate  http://example.com/multiZoneEcsService  http://example.com/alibaba
#  8  http://example.com/compensationMultiZone25      http://www.w3.org/ns/odrl/2/compensate  http://example.com/multiZoneEcsService  http://example.com/alibaba
#  9  http://example.com/compensationMultiZone100     http://www.w3.org/ns/odrl/2/compensate  http://example.com/multiZoneEcsService  http://example.com/alibaba
# 10  http://example.com/customerCreditUsageInterval  http://www.w3.org/ns/odrl/2/use         http://example.com/serviceCredit        http://example.com/customer
# 11  http://example.com/publishAgreement             https://w3id.org/tosl/publish           http://example.com/alibabaECSSLA        http://example.com/alibaba

# %% [markdown]
# #### Provider

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                           actions                                 targets                                assignee
# --  ---------------------------------------------  --------------------------------------  -------------------------------------  -------------------------
#  0  http://example.com/commitmentEC2Region         https://w3id.org/tosla/guarantee        http://example.com/ec2RegionService    http://example.com/amazon
#  1  http://example.com/compensationEC2Region10     http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2RegionService    http://example.com/amazon
#  2  http://example.com/compensationEC2Region30     http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2RegionService    http://example.com/amazon
#  3  http://example.com/compensationEC2Region100    http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2RegionService    http://example.com/amazon
#  4  http://example.com/commitmentEC2Instance       https://w3id.org/tosla/guarantee        http://example.com/ec2InstanceService  http://example.com/amazon
#  5  http://example.com/compensationEC2Instance10   http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon
#  6  http://example.com/compensationEC2Instance30   http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon
#  7  http://example.com/compensationEC2Instance100  http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon
#  8  http://example.com/commitmentPerInstanceHour   https://w3id.org/tosla/guarantee        http://example.com/ec2InstanceService  http://example.com/amazon
#  9  http://example.com/compensatePerHour           http://www.w3.org/ns/odrl/2/compensate  http://example.com/ec2InstanceService  http://example.com/amazon

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                                      actions                                 targets                                                                                                                                                                                                                                                                                                                       assignee
# --  --------------------------------------------------------  --------------------------------------  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------  -------------------------
#  0  http://example.com/commitmentSPlanSingleNode              https://w3id.org/tosla/guarantee        http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  1  http://example.com/compensation7_5_SPlanSingleNode        http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  2  http://example.com/compensation15_SPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  3  http://example.com/compensation25_SPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  4  http://example.com/commitmentSPlanHighAvailability        https://w3id.org/tosla/guarantee        http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
#  5  http://example.com/compensation7_5_SPlanHighAvailability  http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
#  6  http://example.com/compensation15_SPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
#  7  http://example.com/compensation25_SPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceSPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
#  8  http://example.com/commitmentMPlanSingleNode              https://w3id.org/tosla/guarantee        http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
#  9  http://example.com/compensation7_5_MPlanSingleNode        http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 10  http://example.com/compensation15_MPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 11  http://example.com/compensation25_MPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 12  http://example.com/commitmentMPlanHighAvailability        https://w3id.org/tosla/guarantee        http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 13  http://example.com/compensation7_5_MPlanHighAvailability  http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 14  http://example.com/compensation15_MPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 15  http://example.com/compensation25_MPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceMPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 16  http://example.com/commitmentLPlanSingleNode              https://w3id.org/tosla/guarantee        http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 17  http://example.com/compensation7_5_LPlanSingleNode        http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 18  http://example.com/compensation15_LPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 19  http://example.com/compensation25_LPlanSingleNode         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanSingleNode                                                                                                                                                                                                                                                                                     http://example.com/cedalo
# 20  http://example.com/commitmentLPlanHighAvailability        https://w3id.org/tosla/guarantee        http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 21  http://example.com/compensation7_5_LPlanHighAvailability  http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 22  http://example.com/compensation15_LPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 23  http://example.com/compensation25_LPlanHighAvailability   http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceLPlanHighAvailability                                                                                                                                                                                                                                                                               http://example.com/cedalo
# 24  http://example.com/commitmentEnterprisePlan               https://w3id.org/tosla/guarantee        http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 25  http://example.com/compensation7_5_EnterprisePlan         http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 26  http://example.com/compensation15_EnterprisePlan          http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 27  http://example.com/compensation25_EnterprisePlan          http://www.w3.org/ns/odrl/2/compensate  http://example.com/serviceEnterprisePlan                                                                                                                                                                                                                                                                                      http://example.com/cedalo
# 28  http://example.com/serviceChangeNotification              http://www.w3.org/ns/odrl/2/inform      http://example.com/serviceSPlanSingleNode, http://example.com/serviceSPlanHighAvailability, http://example.com/serviceMPlanSingleNode, http://example.com/serviceMPlanHighAvailability, http://example.com/serviceLPlanSingleNode, http://example.com/serviceLPlanHighAvailability, http://example.com/serviceEnterprisePlan  http://example.com/cedalo

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                          actions                                 targets                                 assignee
# --  --------------------------------------------  --------------------------------------  --------------------------------------  --------------------------
#  0  http://example.com/uptimeCommitmentInstance   https://w3id.org/tosla/guarantee        http://example.com/instanceEcsService   http://example.com/alibaba
#  1  http://example.com/compensationInstance10     http://www.w3.org/ns/odrl/2/compensate  http://example.com/instanceEcsService   http://example.com/alibaba
#  2  http://example.com/compensationInstance25     http://www.w3.org/ns/odrl/2/compensate  http://example.com/instanceEcsService   http://example.com/alibaba
#  3  http://example.com/compensationInstance100    http://www.w3.org/ns/odrl/2/compensate  http://example.com/instanceEcsService   http://example.com/alibaba
#  4  http://example.com/uptimeCommitmentMultiZone  https://w3id.org/tosla/guarantee        http://example.com/multiZoneEcsService  http://example.com/alibaba
#  5  http://example.com/compensationMultiZone10    http://www.w3.org/ns/odrl/2/compensate  http://example.com/multiZoneEcsService  http://example.com/alibaba
#  6  http://example.com/compensationMultiZone25    http://www.w3.org/ns/odrl/2/compensate  http://example.com/multiZoneEcsService  http://example.com/alibaba
#  7  http://example.com/compensationMultiZone100   http://www.w3.org/ns/odrl/2/compensate  http://example.com/multiZoneEcsService  http://example.com/alibaba
#  8  http://example.com/publishAgreement           https://w3id.org/tosl/publish           http://example.com/alibabaECSSLA        http://example.com/alibaba

# %% [markdown]
# #### Customer

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                         actions                      targets                              assignee
# --  -------------------------------------------  ---------------------------  -----------------------------------  ---------------------------
#  0  http://example.com/customerClaimEC2Region    https://w3id.org/tosl/claim  http://example.com/ec2RegionService  http://example.com/customer
#  1  http://example.com/customerClaimEC2Instance  https://w3id.org/tosl/claim  http://example.com/ec2RegionService  http://example.com/customer

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                                   actions                      targets                                          assignee
# --  -----------------------------------------------------  ---------------------------  -----------------------------------------------  -----------------------------------------
#  0  http://example.com/customerSPlanSingleNodeClaim        https://w3id.org/tosl/claim  http://example.com/serviceSPlanSingleNode        http://example.com/customerSPlan
#  1  http://example.com/customerSPlanHighAvailabilityClaim  https://w3id.org/tosl/claim  http://example.com/serviceSPlanHighAvailability  http://example.com/customerSPlan
#  2  http://example.com/customerMPlanSingleNodeClaim        https://w3id.org/tosl/claim  http://example.com/serviceMPlanSingleNode        http://example.com/customerMPlan
#  3  http://example.com/customerMPlanHighAvailabilityClaim  https://w3id.org/tosl/claim  http://example.com/serviceMPlanHighAvailability  http://example.com/customerSPlan
#  4  http://example.com/customerLPlanSingleNodeClaim        https://w3id.org/tosl/claim  http://example.com/serviceLPlanSingleNode        http://example.com/customerLPlan
#  5  http://example.com/customerLPlanHighAvailabilityClaim  https://w3id.org/tosl/claim  http://example.com/serviceLPlanHighAvailability  http://example.com/customerLPlan
#  6  http://example.com/customerEnterprisePlanClaim         https://w3id.org/tosl/claim  http://example.com/serviceEnterprisePlan         http://example.com/customerEnterprisePlan

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_duties.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#     duty                                            actions                          targets                                 assignee
# --  ----------------------------------------------  -------------------------------  --------------------------------------  ---------------------------
#  0  http://example.com/customerClaimInstance        https://w3id.org/tosl/claim      http://example.com/instanceEcsService   http://example.com/customer
#  1  http://example.com/customerClaimMultiZone       https://w3id.org/tosl/claim      http://example.com/multiZoneEcsService  http://example.com/customer
#  2  http://example.com/customerCreditUsageInterval  http://www.w3.org/ns/odrl/2/use  http://example.com/serviceCredit        http://example.com/customer

# %% [markdown]
# ## Prohibitions and number of prohibitions

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalProhibitions
# --  -------------------
#  0                    0

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalProhibitions
# --  -------------------
#  0                    0

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/total_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)
# Out:
#       totalProhibitions
# --  -------------------
#  0                    0

# %%
query_file = "../sparql_queries/obligations_permissions_prohibition/get_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# #### Provider

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_provider_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# #### Customer

# %% [markdown]
# - Amazon EC2 SLA

# %%
file_path = "examples/amazon_ec2_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Cedalo SLA

# %%
file_path = "examples/cedalo_sla_2025.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)

# %% [markdown]
# - Alibaba SLA

# %%
file_path = "examples/alibaba_sla.ttl"
query_file = "../sparql_queries/obligations_permissions_prohibition/get_customer_prohibitions.rq" 
run_sparql_query(file_path, query_file, file_format)
